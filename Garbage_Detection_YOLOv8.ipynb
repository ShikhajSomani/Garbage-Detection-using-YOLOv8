# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OvapoMU3DQ8Bm5Lk3LiF")
project = rf.workspace("shikhaj").project("yolov8-trash-detections-pdszv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to yolov8-trash-detections-1 in yolov8:: 100%|██████████| 11320/11320 [00:01<00:00, 7208.73it/s]

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/yolov8-trash-detections-1/data.yaml",
    epochs=15,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-3/weights/best.pt")

results = model.predict(
    source="/content/garbage.jpeg",
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /content/garbage.jpeg: 320x640 2 plastic bags, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to /content/runs/detect/predict-3

# %%
import os

os.listdir("/content/runs/detect/predict")
# Out:
# ['garbage.jpg']

# %%
from IPython.display import Image

Image("/content/runs/detect/predict/garbage.jpg")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/runs/detect/train-3/weights/best.pt /content/drive/MyDrive/
